# %% [markdown]
# # Custom Agent Integration
# If you are using a custom framework, you can use the `AgentMonitor` class to track steps manually.

# %%
from src.monitor import AgentMonitor
monitor = AgentMonitor()
monitor.set_query('My task')
monitor.add_step('thought', 'action', 'obs')
report = monitor.get_report()
report.summary()
