# %% [markdown]
# # LangChain Integration
# This notebook demonstrates how to easily integrate AgentSight with LangChain.

# %%
from src.integrations.langchain import AgentSightCallback
# Assuming you have an agent
# agent.run('My task', callbacks=[AgentSightCallback()])
